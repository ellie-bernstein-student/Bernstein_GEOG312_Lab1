# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/geog-312/blob/master/labs/lab_01.ipynb)
# [![image](https://binder.pangeo.io/badge_logo.svg)](https://gishub.org/geog312-pangeo)

# %%
from datetime import datetime

now = datetime.now()
print(f"Submitted time: {now}")
# Out:
# Submitted time: 2023-09-01 20:57:48.722829

# %% [markdown]
# ## Question 1
#
# **Simple Message:** Assign a message to a variable, and then print that message.

# %%
message = "Hello!"
print(message)
# Out:
# Hello!

# %% [markdown]
# ## Question 2
# **Simple Messages:** Assign a message to a variable, and print that message. Then change the value of the variable to a new message, and print the new message.

# %%
message="Hello!"
print(message)
message="Hi!"
print(message)
# Out:
# Hello!
# Hi!

# %% [markdown]
# ## Question 3
# **Personal Message:** Use a variable to represent a person’s name, and print a message to that person. Your message should be simple, such as, “Hello Eric, would you like to learn some Python today?”

# %%
name = "Maddie"
print("Dear", name, end=", ")
print("how are you doing?")
# Out:
# Dear Maddie, how are you doing?

# %% [markdown]
# ## Question 4
# **Name Cases:** Use a variable to represent a person’s name, and then print that person’s name in lowercase, uppercase, and title case.

# %%
name = "Maddie"
print(name.lower())
print(name.upper())
print(name.title())
# Out:
# maddie
# MADDIE
# Maddie

# %% [markdown]
# ## Question 5
# **Famous Quote:** Find a quote from a famous person you admire. Print the quote and the name of its author. Your output should look something like the following, including the quotation marks:
# ```
# Albert Einstein once said, “A person who never made a mistake never tried anything new.”
# ```

# %%
#Ellie Bernstein, 09-01-2023, In this code, I printed two string codes and used the "end =" function to remove spaces surroinding the quotation marks.
author = "Tupac Shakur"
quote = "They have money for war but can't feed the poor"
print(author, "once said,", end=" \"")
print(quote, end=".")
print("\"")
# Out:
# Tupac Shakur once said, "They have money for war but can't feed the poor."

# %% [markdown]
# ## Question 6
# **Famous Quote 2:** Repeat Exercise 2-5, but this time, represent the famous person’s name using a variable called famous_person. Then compose your message and represent it with a new variable called message. Print your
# message.

# %%
message="Hello!"
print(message)
message="Hi!"
print(message)
famous_person = "Tupac Shakur"
print("Hello", famous_person, end=", ")
print("how are you doing?")
print(famous_person.lower())
print(famous_person.upper())
print(famous_person.title())
message = "They have money for war but can't feed the poor"
print(famous_person, "once said,", end=" \"")
print(message, end=".")
print("\"")
# Out:
# Hello!
# Hi!
# Hello Tupac Shakur, how are you doing?
# tupac shakur
# TUPAC SHAKUR
# Tupac Shakur
# Tupac Shakur once said, "They have money for war but can't feed the poor."

# %% [markdown]
# ## Question 7
# **Stripping Names:** Use a variable to represent a person’s name, and include some whitespace characters at the beginning and end of the name. Make sure you use each character combination, "\t" and "\n", at least once.
# Print the name once, so the whitespace around the name is displayed. Then print the name using each of the three stripping functions, lstrip(), rstrip(), and strip().

# %%
#Ellie Bernsstein, 09-01-2023, I used the lstrip(), rstrip(), and strip() functions to remove white-space on the left, right, and both sides of string text.
name = " \t Melody \n "
print(name)
print(name.lstrip())
print(name.rstrip())
print(name.strip())
# Out:
#  	 Melody
#
# Melody
#
#  	 Melody
# Melody

# %% [markdown]
# ## Question 8
# **Number Eight:** Write addition, subtraction, multiplication, and division operations that each result in the number 8. Be sure to enclose your operations in print() calls to see the results. You should create four lines that look like this:
#
# ```
# print(5 + 3)
# ```
# Your output should simply be four lines with the number 8 appearing once on each line.

# %%
print(4+4)
print(10-2)
print(2*4)
print(int(80/10))
# Out:
# 8
# 8
# 8
# 8

# %% [markdown]
# ## Question 9
# **Favorite Number:**  Use a variable to represent your favorite number. Then, using that variable, create a message that reveals your favorite number. Print that message.

# %%
favorite_number = 8
message1 = "Hey man, look over there. That guy has"
message2 = "watermelons in his shopping cart."
print(message1, favorite_number, message2)
# Out:
# Hey man, look over there. That guy has 8 watermelons in his shopping cart.

# %% [markdown]
# ## Question 10
# **Adding Comments:** Choose two of the programs you’ve written, and add at least one comment to each. If you don’t have anything specific to write because your programs are too simple at this point, just add your name and
# the current date at the top of each program file. Then write one sentence describing what the program does.

# %%
#done on number 5 and 7
